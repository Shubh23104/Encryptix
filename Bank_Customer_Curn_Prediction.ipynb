# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubh23104/Encryptix/blob/main/Bank_Customer_Curn_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.drop(['RowNumber'], axis=1, inplace= True)

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df= df.join(pd.get_dummies(df['Geography'], prefix= 'Geo').astype('int'))

# %%
df.drop(['Geography'], axis=1, inplace= True)

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore  Gender  Age  Tenure    Balance  \
# 0    15634602  Hargrave          619  Female   42       2       0.00
# 1    15647311      Hill          608  Female   41       1   83807.86
# 2    15619304      Onio          502  Female   42       8  159660.80
# 3    15701354      Boni          699  Female   39       1       0.00
# 4    15737888  Mitchell          850  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Geo_France  Geo_Germany  Geo_Spain
# 0           1            0          0
# 1           0            0          1
# 2           1            0          0
# 3           1            0          0
# 4           0            0          1

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df['Gender']= df['Gender'].astype('str').apply(lambda x: 1 if x=='Female' else 0)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 0    5457
# 1    4543
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited', 'Geo_France', 'Geo_Germany', 'Geo_Spain'],
#       dtype='object')

# %%
df= df[['CustomerId', 'Surname', 'CreditScore', 'Gender', 'Age', 'Tenure',
       'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary', 'Geo_France', 'Geo_Germany', 'Geo_Spain', 'Exited']]
df.head()
# Out:
#    CustomerId   Surname  CreditScore  Gender  Age  Tenure    Balance  \
# 0    15634602  Hargrave          619       1   42       2       0.00
# 1    15647311      Hill          608       1   41       1   83807.86
# 2    15619304      Onio          502       1   42       8  159660.80
# 3    15701354      Boni          699       1   39       1       0.00
# 4    15737888  Mitchell          850       1   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Geo_France  \
# 0              1          1               1        101348.88           1
# 1              1          0               1        112542.58           0
# 2              3          1               0        113931.57           1
# 3              2          0               0         93826.63           1
# 4              1          1               1         79084.10           0
#
#    Geo_Germany  Geo_Spain  Exited
# 0            0          0       1
# 1            0          1       0
# 2            0          0       1
# 3            0          0       0
# 4            0          1       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Gender           10000 non-null  int64
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  float64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Geo_France       10000 non-null  int64
#  12  Geo_Germany      10000 non-null  int64
#  13  Geo_Spain        10000 non-null  int64
#  14  Exited           10000 non-null  int64
# dtypes: float64(2), int64(12), object(1)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[['CreditScore', 'Gender', 'Age', 'Tenure',
       'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary', 'Geo_France', 'Geo_Germany', 'Geo_Spain', 'Exited']].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_999d3_row0_col0, #T_999d3_row1_col1, #T_999d3_row2_col2, #T_999d3_row3_col3, #T_999d3_row4_col4, #T_999d3_row5_col5, #T_999d3_row6_col6, #T_999d3_row7_col7, #T_999d3_row8_col8, #T_999d3_row9_col9, #T_999d3_row10_col10, #T_999d3_row11_col11, #T_999d3_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_999d3_row0_col1, #T_999d3_row3_col0, #T_999d3_row4_col8, #T_999d3_row5_col8, #T_999d3_row6_col2, #T_999d3_row8_col0, #T_999d3_row9_col3, #T_999d3_row10_col3, #T_999d3_row10_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T
col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_999d3_row7_col11 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_999d3_row8_col12 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_999d3_row9_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_999d3_row9_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_999d3_row9_col7 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_999d3_row10_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_999d3_row10_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_999d3_row10_col11 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_999d3_row10_col12 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_999d3_row11_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_999d3_row11_col7 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_999d3_row11_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_999d3_row12_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_999d3_row12_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_999d3_row12_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_999d3_row12_col9 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_999d3_row12_col10 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_999d3_row12_col11 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# </style>
# <table id="T_999d3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_999d3_level0_col0" class="col_heading level0 col0" >CreditScore</th>
#       <th id="T_999d3_level0_col1" class="col_heading level0 col1" >Gender</th>
#       <th id="T_999d3_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_999d3_level0_col3" class="col_heading level0 col3" >Tenure</th>
#       <th id="T_999d3_level0_col4" class="col_heading level0 col4" >Balance</th>
#       <th id="T_999d3_level0_col5" class="col_heading level0 col5" >NumOfProducts</th>
#       <th id="T_999d3_level0_col6" class="col_heading level0 col6" >HasCrCard</th>
#       <th id="T_999d3_level0_col7" class="col_heading level0 col7" >IsActiveMember</th>
#       <th id="T_999d3_level0_col8" class="col_heading level0 col8" >EstimatedSalary</th>
#       <th id="T_999d3_level0_col9" class="col_heading level0 col9" >Geo_France</th>
#       <th id="T_999d3_level0_col10" class="col_heading level0 col10" >Geo_Germany</th>
#       <th id="T_999d3_level0_col11" class="col_heading level0 col11" >Geo_Spain</th>
#       <th id="T_999d3_level0_col12" class="col_heading level0 col12" >Exited</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_999d3_level0_row0" class="row_heading level0 row0" >CreditScore</th>
#       <td id="T_999d3_row0_col0" class="data

# %%
X= df[['CreditScore', 'Gender', 'Age', 'Tenure',
       'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary', 'Geo_France', 'Geo_Germany', 'Geo_Spain']]
y= df['Exited']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import  train_test_split
sc= StandardScaler()
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2)
X_train_scld= sc.fit_transform(X_train)
X_test_scld= sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
lr.fit(X_train_scld, y_train)
y_pred_lr= lr.predict(X_test_scld)
y_pred_lr
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
acc_lr= accuracy_score(y_test, y_pred_lr)
acc_lr
# Out:
# 0.813

# %%
from sklearn.metrics import confusion_matrix
cm= pd.DataFrame(confusion_matrix(y_test, y_pred_lr))
cm
# Out:
#       0   1
# 0  1541  61
# 1   313  85

# %%
from sklearn.ensemble import RandomForestClassifier
rfc= RandomForestClassifier(n_estimators=100, criterion='gini')
rfc.fit(X_train_scld, y_train)
y_pred_rfc= rfc.predict(X_test_scld)
y_pred_rfc
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
acc_rfc= accuracy_score(y_test, y_pred_rfc)
acc_rfc
# Out:
# 0.8625

# %%
from sklearn.metrics import confusion_matrix
cm_rfc= confusion_matrix(y_test, y_pred_rfc)
cm_rfc= pd.DataFrame(cm_rfc)
cm_rfc
# Out:
#       0    1
# 0  1548   54
# 1   221  177

# %%
from sklearn.svm import SVC
svc= SVC(kernel= 'rbf', probability=True)
svc.fit(X_train_scld, y_train)
y_pred_svc= svc.predict(X_test_scld)
y_pred_svc
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
acc_svc= accuracy_score(y_test, y_pred_svc)
acc_svc
# Out:
# 0.855

# %%
from sklearn.metrics import confusion_matrix
cm_svc= confusion_matrix(y_test, y_pred_svc)
cm_svc= pd.DataFrame(cm_svc)
cm_svc
# Out:
#       0    1
# 0  1563   39
# 1   251  147
